# %%
import pandas as pd
from toolz import first

# %%
file_iter = pd.read_csv("./MinneMUDAC_raw_files/2002_metro_tax_parcels.txt", sep= "|", chunksize= 500)
first_chunk = first(file_iter)
first_chunk.columns
# Out:
# Index(['ACRES_DEED', 'ACRES_POLY', 'AGPRE_ENRD', 'AGPRE_EXPD', 'AG_PRESERV',
#        'BASEMENT', 'BLDG_NUM', 'BLOCK', 'CITY', 'CITY_USPS', 'COOLING',
#        'COUNTY_ID', 'DWELL_TYPE', 'EMV_BLDG', 'EMV_LAND', 'EMV_TOTAL',
#        'FIN_SQ_FT', 'GARAGE', 'GARAGESQFT', 'GREEN_ACRE', 'HEATING',
#        'HOMESTEAD', 'HOME_STYLE', 'LANDMARK', 'LOT', 'MULTI_USES', 'NUM_UNITS',
#        'OPEN_SPACE', 'OWNER_MORE', 'OWNER_NAME', 'OWN_ADD_L1', 'OWN_ADD_L2',
#        'OWN_ADD_L3', 'OWN_NAME', 'PARC_CODE', 'PIN', 'PIN_1', 'PLAT_NAME',
#        'PREFIXTYPE', 'PREFIX_DIR', 'SALE_DATE', 'SALE_VALUE', 'SCHOOL_DST',
#        'SPEC_ASSES', 'STREET', 'STREETNAME', 'STREETTYPE', 'STRUC_TYPE',
#        'SUFFIX_DIR', 'Shape_Area', 'Shape_Leng', 'TAX_ADD_L1', 'TAX_ADD_L2',
#        'TAX_ADD_L3', 'TAX_ADD_LI', 'TAX_CAPAC', 'TAX_EXEMPT', 'TAX_NAME',
#        'TOTAL_TAX', 'UNIT_INFO', 'USE1_DESC', 'USE2_DESC', 'USE3_DESC',
#        'USE4_DESC', 'WSHD_DIST', 'XUSE1_DESC', 'XUSE2_DESC', 'XUSE3_DESC',
# ...

# %%
files_iter =[pd.read_csv("./MinneMUDAC_raw_files/"+ str(file) +"_metro_tax_parcels.txt", sep= "|", chunksize= 500) for file in range(2002, 2016) if file != 2003]
first_chunks = [first(file).columns for file in files_iter]      
first_chunks
header_sets =[set(file) for file in first_chunks]
header_sets
# Out:
# [{'ACRES_DEED',
#   'ACRES_POLY',
#   'AGPRE_ENRD',
#   'AGPRE_EXPD',
#   'AG_PRESERV',
#   'BASEMENT',
#   'BLDG_NUM',
#   'BLOCK',
#   'CITY',
#   'CITY_USPS',
#   'COOLING',
#   'COUNTY_ID',
#   'DWELL_TYPE',
#   'EMV_BLDG',
#   'EMV_LAND',
#   'EMV_TOTAL',
#   'FIN_SQ_FT',
#   'GARAGE',
#   'GARAGESQFT',
#   'GREEN_ACRE',
#   'HEATING',
#   'HOMESTEAD',
#   'HOME_STYLE',
#   'LANDMARK',
#   'LOT',
#   'MULTI_USES',
#   'NUM_UNITS',
#   'OPEN_SPACE',
#   'OWNER_MORE',
#   'OWNER_NAME',
#   'OWN_ADD_L1',
#   'OWN_ADD_L2',
#   'OWN_ADD_L3',
#   'OWN_NAME',
#   'PARC_CODE',
#   'PIN',
#   'PIN_1',
#   'PLAT_NAME',
#   'PREFIXTYPE',
#   'PREFIX_DIR',
#   'SALE_DATE',
#   'SALE_VALUE',
#   'SCHOOL_DST',
#   'SPEC_ASSES',
#   'STREET',
#   'STREETNAME',
#   'STREETTYPE',
#   'STRUC_TYPE',
#   'SUFFIX_DIR',
#   'Shape_Area',
#   'Shape_Leng',
#   'TAX_ADD_L1',
#   'TAX_ADD_L2',
#   'TAX_ADD_L3',
#   'TAX_ADD_LI',
#   'TAX_CAPAC',
#   'TAX_EXEMPT',
#   'TAX_NAME',
#   'TOTAL_TAX',
# ...

# %%
[(year, len(h)) for year, h in zip(range(2002, 2016), header_sets) if year != 2003]
# Out:
# [(2002, 75),
#  (2004, 70),
#  (2005, 70),
#  (2006, 72),
#  (2007, 72),
#  (2008, 72),
#  (2009, 71),
#  (2010, 70),
#  (2011, 70),
#  (2012, 70),
#  (2013, 74),
#  (2014, 70)]

# %%
cnt = 0
for n in range(5):
    cnt = cnt + n
cnt
# Out:
# 10

# %%
all_cols = set([])
for header_set in header_sets:
    all_cols = all_cols.union(header_set)
all_cols
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'Garage',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'Homestead',
#  'ID',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'OWN_NAME',
#  'PARC_CODE',
#  'PIN',
#  'PIN_1',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREET',
#  'STREETNAME',
#  'STREETTYPE',
#  'STRUC_TYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Le_1',
#  'Shape_Leng',
#  'Shape_STAr',
#  'Shape_STLe',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_ADD_LI',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
# ...

# %%
len(common_cols)
# Out:
# 70

# %%
common_cols = all_cols
for header_set in header_sets:
    common_cols = common_cols.intersection(header_set)
common_cols
# Out:
# {'ACRES_DEED',
#  'ACRES_POLY',
#  'AGPRE_ENRD',
#  'AGPRE_EXPD',
#  'AG_PRESERV',
#  'BASEMENT',
#  'BLDG_NUM',
#  'BLOCK',
#  'CITY',
#  'CITY_USPS',
#  'COOLING',
#  'COUNTY_ID',
#  'DWELL_TYPE',
#  'EMV_BLDG',
#  'EMV_LAND',
#  'EMV_TOTAL',
#  'FIN_SQ_FT',
#  'GARAGE',
#  'GARAGESQFT',
#  'GREEN_ACRE',
#  'HEATING',
#  'HOMESTEAD',
#  'HOME_STYLE',
#  'LANDMARK',
#  'LOT',
#  'MULTI_USES',
#  'NUM_UNITS',
#  'OPEN_SPACE',
#  'OWNER_MORE',
#  'OWNER_NAME',
#  'OWN_ADD_L1',
#  'OWN_ADD_L2',
#  'OWN_ADD_L3',
#  'PARC_CODE',
#  'PIN',
#  'PLAT_NAME',
#  'PREFIXTYPE',
#  'PREFIX_DIR',
#  'SALE_DATE',
#  'SALE_VALUE',
#  'SCHOOL_DST',
#  'SPEC_ASSES',
#  'STREETNAME',
#  'STREETTYPE',
#  'SUFFIX_DIR',
#  'Shape_Area',
#  'Shape_Leng',
#  'TAX_ADD_L1',
#  'TAX_ADD_L2',
#  'TAX_ADD_L3',
#  'TAX_CAPAC',
#  'TAX_EXEMPT',
#  'TAX_NAME',
#  'TOTAL_TAX',
#  'UNIT_INFO',
#  'USE1_DESC',
#  'USE2_DESC',
#  'USE3_DESC',
#  'USE4_DESC',
#  'WSHD_DIST',
#  'XUSE1_DESC',
#  'XUSE2_DESC',
# ...

# %%
len(common_cols)
# Out:
# 70

# %%
diff_cols = []
for header_set in header_sets:
    diff_cols = header_set.difference(common_cols)
    print(len(diff_cols), diff_cols)
# Out:
# 5 {'TAX_ADD_LI', 'OWN_NAME', 'PIN_1', 'STREET', 'STRUC_TYPE'}
# 1 {'ID'}
# 0 set()
# 0 set()
# 2 {'Homestead', 'Garage'}
# 2 {'Homestead', 'Garage'}
# 2 {'Homestead', 'Garage'}
# 1 {'Garage'}
# 0 set()
# 0 set()
# 0 set()
# 4 {'Shape_STAr', 'TORRENS', 'Shape_STLe', 'Shape_Le_1'}
# 0 set()

# %%
[(year, len(diff_cols)) for year in zip(range(2002, 2016)) if year != 2003]
