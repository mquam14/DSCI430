# %%
from project_data_Quam import common_columns
from project_data_Quam import *

# %%
common_columns[1:5]
# Out:
# ['AGPRE_EXPD', 'EMV_TOTAL', 'TAX_ADD_L1', 'GARAGE']

# %%
#new_xref.lat_long.head()

# %%
len(lat_long_code_dict)
# Out:
# 2300453

# %%
lat_long_name_dict
# Out:
# {('45.31906', '-93.21532'): 'Coon Lake',
#  ('45.3177', '-93.21605'): 'Coon Lake',
#  ('45.3177', '-93.21748'): 'Coon Lake',
#  ('45.30032', '-93.2544'): 'Ham Lake',
#  ('45.32033', '-93.21421'): 'Coon Lake',
#  ('45.29976', '-93.20252'): 'Ham Lake',
#  ('45.29976', '-93.20213'): 'Ham Lake',
#  ('45.29976', '-93.20174'): 'Ham Lake',
#  ('45.29892', '-93.23874'): 'Ham Lake',
#  ('45.32042', '-93.22467'): 'Coon Lake',
#  ('45.29898', '-93.21606'): 'Ham Lake',
#  ('45.29895', '-93.21572'): 'Ham Lake',
#  ('45.31444', '-93.25838'): 'Ham Lake',
#  ('45.30375', '-93.20777'): 'Ham Lake',
#  ('45.30073', '-93.2508'): 'Ham Lake',
#  ('45.30996', '-93.21388'): 'Ham Lake',
#  ('45.30927', '-93.21385'): 'Ham Lake',
#  ('45.30912', '-93.21112'): 'Ham Lake',
#  ('45.2981', '-93.21491'): 'Ham Lake',
#  ('45.29812', '-93.21432'): 'Ham Lake',
#  ('45.3079', '-93.2036'): 'Coon Lake',
#  ('45.30597', '-93.26119'): 'Ham Lake',
#  ('45.30548', '-93.26427'): 'Ham Lake',
# ...

# %%
lat_long_dist
# Out:
# {('45.31906', '-93.21532'): 6131.481447303562,
#  ('45.3177', '-93.21605'): 6186.855984514206,
#  ('45.3177', '-93.21748'): 6298.9821224726475,
#  ('45.30032', '-93.2544'): 5466.087149101658,
#  ('45.32033', '-93.21421'): 6049.653920658666,
#  ('45.29976', '-93.20252'): 4931.217968831946,
#  ('45.29976', '-93.20213'): 4940.1472641891205,
#  ('45.29976', '-93.20174'): 4949.249656313985,
#  ('45.29892', '-93.23874'): 4839.608811971191,
#  ('45.32042', '-93.22467'): 6869.373206912029,
#  ('45.29898', '-93.21606'): 4648.329373850986,
#  ('45.29895', '-93.21572'): 4647.163630279443,
#  ('45.31444', '-93.25838'): 7007.168520979087,
#  ('45.30375', '-93.20777'): 5262.703157694943,
#  ('45.30073', '-93.2508'): 5375.977652307173,
#  ('45.30996', '-93.21388'): 5878.723355924489,
#  ('45.30927', '-93.21385'): 5802.5760866462,
#  ('45.30912', '-93.21112'): 5809.730295764693,
#  ('45.2981', '-93.21491'): 4558.908458009229,
#  ('45.29812', '-93.21432'): 4565.9480358415085,
# ...

# %%
ex = ('45.41192', '-93.33711')
ex in ll_set
# Out:
# True
